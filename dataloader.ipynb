# %%
from SoccerNet.Downloader import SoccerNetDownloader

my_downloader = SoccerNetDownloader(LocalDirectory="C:/Users/Ilias/documents/cours_mines/tr/projet/data/data")
my_downloader.password = "s0cc3rn3t"
my_downloader.downloadGames(files=["1_ResNET_TF2_PCA512.npy", "2_ResNET_TF2_PCA512.npy"], 
                            split=["train", "valid", "test"])

# Téléchargement des labels (JSON)
my_downloader.downloadGames(files=["Labels-v3.json"], split=["train", "valid", "test"])
# Out:
# C:/Users/Ilias/documents/cours_mines/tr/projet/data/data\england_epl\2014-2015\2015-02-21 - 18-00 Chelsea 1 - 1 Burnley\1_ResNET_TF2_PCA512.npy already exists
# C:/Users/Ilias/documents/cours_mines/tr/projet/data/data\england_epl\2014-2015\2015-02-21 - 18-00 Chelsea 1 - 1 Burnley\2_ResNET_TF2_PCA512.npy already exists
# C:/Users/Ilias/documents/cours_mines/tr/projet/data/data\england_epl\2014-2015\2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal\1_ResNET_TF2_PCA512.npy already exists
# C:/Users/Ilias/documents/cours_mines/tr/projet/data/data\england_epl\2014-2015\2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal\2_ResNET_TF2_PCA512.npy already exists
# C:/Users/Ilias/documents/cours_mines/tr/projet/data/data\england_epl\2014-2015\2015-02-21 - 18-00 Swansea 2 - 1 Manchester United\1_ResNET_TF2_PCA512.npy already exists
# C:/Users/Ilias/documents/cours_mines/tr/projet/data/data\england_epl\2014-2015\2015-02-21 - 18-00 Swansea 2 - 1 Manchester United\2_ResNET_TF2_PCA512.npy already exists
# ...
